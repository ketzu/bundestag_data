# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set_palette(['Blue', 'Black', 'Yellow', 'Grey', 'Green', 'Magenta', 'Red'])

# %%
data = pd.read_csv("bundestag.csv")
data
# Out:
#            Name    Vorname Fraktion    2017    2018    2019    2020   2021  \
# 0       Komning     Enrico      AfD  262000  338500  262000  240500  66500
# 1     Chrupalla       Tino      AfD   24000  166500  151500   78500      0
# 2       Neumann  Christoph      AfD    3500   30000   15000   57000   8000
# 3        Felser      Peter      AfD    4000   24000   24000   24000  10000
# 4          Pohl     Jürgen      AfD    1000   23000   31500    9500      0
# ..          ...        ...      ...     ...     ...     ...     ...    ...
# 597  Weingarten    Dr. Joe      SPD       0       0       0       0      0
# 598    Westphal      Bernd      SPD       0       0       0       0      0
# 599     Ziegler     Dagmar      SPD       0       0       0       0      0
# 600      Zierke     Stefan      SPD       0       0       0       0      0
# 601  Zimmermann   Dr. Jens      SPD       0       0       0       0      0
#
#       Gesamt
# 0    1169500
# 1     420500
# 2     113500
# ...

# %%
sns.scatterplot(x='Fraktion', y='2017', data=data, hue='Fraktion')
# Out:
# <AxesSubplot:xlabel='Fraktion', ylabel='2017'>

# %%
sns.scatterplot(x='Fraktion', y='2021', data=data, hue='Fraktion')
# Out:
# <AxesSubplot:xlabel='Fraktion', ylabel='2021'>

# %%
sns.scatterplot(x='Fraktion', y='Gesamt', data=data, hue='Fraktion')
# Out:
# <AxesSubplot:xlabel='Fraktion', ylabel='Gesamt'>
